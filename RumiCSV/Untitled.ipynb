# %% [markdown]
# # Najboljši rumi

# %% [markdown]
# V projektni nalogi sem zajela podatke vseh rumov na spletni strani https://www.rumratings.com/brands.
#
#
# Zbrala sem naslednje podatke:
#
#         • ime ruma
#         • drzava
#         • stil
#         • število slasov
#         • cena
#         • ocena
#
#
# V nadaljevanju bom obravnavala odvisnost cene od države in stila, število rumov na državo, najbolje ocenjeni rumi, kateri rum bi bil najboljš nakup...

# %%
import pandas as pd
# %matplotlib inline

pd.options.display.max_rows = 20

# %% [markdown]
# Za začetek si oglejmo vse podatke, zbrane v tabeli:

# %%
rumi = pd.read_csv('podatki.csv')
rumi
# Out:
#                                                    Name             Country  \
# 0                        Diplomatico Reserva Exclusiva            Venezuela
# 1                                             Pyrat XO             Anguilla
# 2                                  Kraken Black Spiced             Trinidad
# 3                       Plantation XO 20th Anniversary            Caribbean
# 4                                    El Dorado 12-Year               Guyana
# 5                                     Bacardi Superior          Puerto Rico
# 6                                        Ron Zacapa XO            Guatemala
# 7                                 Ron Zacapa 23 Solera            Guatemala
# 8                       Matusalem Gran Reserva 15-Year   Dominican Republic
# 9                    El Dorado Special Reserve 15-Year               Guyana
# ...                                                 ...                 ...
# 3871                        Blue Bay B. Superior White            Mauritius
# 3872                                 Mangoustan's Cafe           Martinique
# 3873                              Ron Medellin 30 años             Colombia
# 3874                                    Heejoy Origins               France
# 3875                              Sam Smith's Boatyard   Dominican Republic
# 3876                                     Malahat Light                  USA
# 3877  Berry Bros. &amp; Rudd Trinidad Caroni 19-Year...             Jamaica
# 3878               Saint James Cuvee 250th Anniversary           Martinique
# 3879              Manulele Distillery  Ko Hana Kea Rhum                 USA
# 3880                             Ron Cabo Blanco Black                 Peru
#
#                Type  Ratings Price_USD  Rating
# 0              Aged     1235     38.64     8.1
# 1              Aged      655     23.73     6.3
# 2            Spiced      757      17.3     6.2
# 3              Aged      626     54.76     8.6
# 4              Aged      647     36.11     7.8
# 5             Light      367     14.26     3.7
# 6              Aged      431      94.8     8.8
# 7              Aged     1108      50.7     7.7
# 8              Aged      368     28.93     6.4
# 9              Aged      479     52.61     8.1
# ...             ...      ...       ...     ...
# 3871          Light        1     18.49     3.0
# 3872       Flavored        1      None     4.0
# 3873           Aged        1      None     8.0
# 3874           Aged        1      None     5.0
# 3875           Gold        1      None     6.0
# 3876          Light        1      None     4.0
# 3877           Aged        1      None     9.0
# 3878           Aged        1   1120.57     3.0
# 3879  Rhum Agricole        1      None     7.0
# 3880           Dark        1      None     2.0
#
# [3881 rows x 6 columns]

# %%
#Ker je veliko rumov neocenjenih, mi to uniči analizo, zato se odločim da take vržem iz igre pri določenih analizah
rumi1 = rumi[rumi.Ratings > 0]
rumi1
# Out:
#                                                    Name             Country  \
# 0                        Diplomatico Reserva Exclusiva            Venezuela
# 1                                             Pyrat XO             Anguilla
# 2                                  Kraken Black Spiced             Trinidad
# 3                       Plantation XO 20th Anniversary            Caribbean
# 4                                    El Dorado 12-Year               Guyana
# 5                                     Bacardi Superior          Puerto Rico
# 6                                        Ron Zacapa XO            Guatemala
# 7                                 Ron Zacapa 23 Solera            Guatemala
# 8                       Matusalem Gran Reserva 15-Year   Dominican Republic
# 9                    El Dorado Special Reserve 15-Year               Guyana
# ...                                                 ...                 ...
# 3871                        Blue Bay B. Superior White            Mauritius
# 3872                                 Mangoustan's Cafe           Martinique
# 3873                              Ron Medellin 30 años             Colombia
# 3874                                    Heejoy Origins               France
# 3875                              Sam Smith's Boatyard   Dominican Republic
# 3876                                     Malahat Light                  USA
# 3877  Berry Bros. &amp; Rudd Trinidad Caroni 19-Year...             Jamaica
# 3878               Saint James Cuvee 250th Anniversary           Martinique
# 3879              Manulele Distillery  Ko Hana Kea Rhum                 USA
# 3880                             Ron Cabo Blanco Black                 Peru
#
#                Type  Ratings Price_USD  Rating
# 0              Aged     1235     38.64     8.1
# 1              Aged      655     23.73     6.3
# 2            Spiced      757      17.3     6.2
# 3              Aged      626     54.76     8.6
# 4              Aged      647     36.11     7.8
# 5             Light      367     14.26     3.7
# 6              Aged      431      94.8     8.8
# 7              Aged     1108      50.7     7.7
# 8              Aged      368     28.93     6.4
# 9              Aged      479     52.61     8.1
# ...             ...      ...       ...     ...
# 3871          Light        1     18.49     3.0
# 3872       Flavored        1      None     4.0
# 3873           Aged        1      None     8.0
# 3874           Aged        1      None     5.0
# 3875           Gold        1      None     6.0
# 3876          Light        1      None     4.0
# 3877           Aged        1      None     9.0
# 3878           Aged        1   1120.57     3.0
# 3879  Rhum Agricole        1      None     7.0
# 3880           Dark        1      None     2.0
#
# [2953 rows x 6 columns]

# %% [markdown]
# Najprej poglejmo, katerih stilov je največ:

# %%
rumi.groupby('Type').size().sort_values(ascending=False)
# Out:
# Type
# Aged             1776
# Gold              578
# Light             477
# Flavored          357
# Spiced            218
# Rhum Agricole     159
# Dark              145
# Overproof          76
# Cachaca            53
# n/a                42
# dtype: int64

# %%
rumi.groupby('Type').size().sort_values(ascending=False).plot(kind='pie', figsize=(5, 5), fontsize=12, title='Type')

# %% [markdown]
# Največ jih je torej staranih.
# Od kje pa prihaja največ rumov?

# %%
rumi.groupby('Country').size().sort_values(ascending=False)
# Out:
# Country
# USA                   419
# Caribbean             389
# Martinique            274
# Dominican Republic    193
# Guadeloupe            146
# UK                    128
# Cuba                  123
# Puerto Rico           116
# Barbados              115
# Guyana                102
#                      ...
# Rwanda                  1
# Portugal                1
# Combination             1
# Mexique                 1
# London                  1
# Hungary                 1
# Guyane                  1
# French Guyana           1
# France / Cuba           1
# usa                     1
# dtype: int64

# %%
rumi.groupby('Country').size().sort_values(ascending=False)[rumi.groupby('Country').size()>80].plot(kind='bar', figsize = (10, 7), fontsize = 13)

# %% [markdown]
# Kot lahko vidimo na zgornjem grafu, jih je največ iz Združenih držav Amerike.
#
# Sedaj lahko pogledamo, kateri stili so v posameznih državah najbolj priljubljeni.

# %%
rumi.groupby(['Country', 'Type']).size().sort_values(ascending=False)
# Out:
# Country             Type
# Caribbean           Aged             291
# Martinique          Aged             140
# Dominican Republic  Aged             111
# USA                 Light            107
# Guadeloupe          Aged              89
# USA                 Gold              87
# UK                  Aged              83
# Martinique          Rhum Agricole     82
# USA                 Spiced            80
# Guyana              Aged              68
#                                     ...
# Curacao             Dark               1
#                     Gold               1
#                     Light              1
#                     Spiced             1
# Paraguay            Rhum Agricole      1
#                     Aged               1
# Czech Republic      n/a                1
# Nicaragua           Flavored           1
# Newfoundland        Spiced             1
# usa                 Spiced             1
# dtype: int64

# %%
# po oceni razporejeni rumi
rumi[['Name','Country', 'Rating']].sort_values('Rating', ascending=False)
# Out:
#                                                    Name  \
# 3699                                     Bohemio Honey
# 399                                UF30E Uitvlugt 1990
# 3062                                        UF30E 1985
# 723                              Punta Cana Silver Dry
# 3660                       Hercules Superior XXX White
# 3662                    Karukera Single Cask Sauternes
# 711                   Rum Nation Demerara 1989 23-Year
# 3601                         Barbancourt Cuvee 150 Ans
# 681                                    Rumson's Coffee
# 3758                          UF30E Diamond 1999 64,7%
# ...                                                 ...
# 1266                                       Toucan Boco
# 1267                 Sea Wynde 2.nd Edition  Pot Still
# 1268                        Canefire Canefire White UP
# 1269                                       Barton Gold
# 1270                     Cadenhead's Brazilian 13-Year
# 1271  Diplomatico Distillery Collection No1 Batch Ke...
# 1296                                   Arehucas Mature
# 1297                  Belmont Estate Caribbean Coconut
# 1298                                 Villa Rica Blanco
# 1149                        Bristol Classic Cuban 2003
#
#                     Country  Rating
# 3699                 Panama    10.0
# 399                  Guyana    10.0
# 3062                 Guyana    10.0
# 723      Dominican Republic    10.0
# 3660                  India    10.0
# 3662             Guadeloupe    10.0
# 711                   Italy    10.0
# 3601                  Haiti    10.0
# 681                     USA    10.0
# 3758                 Guyana    10.0
# ...                     ...     ...
# 1266                 Guyana     0.0
# 1267  Jamaica &amp; Guyana      0.0
# 1268              Australia     0.0
# 1269                    USA     0.0
# 1270                     UK     0.0
# 1271              Venezuela     0.0
# 1296                  Spain     0.0
# 1297  Saint Kitts and Nevis     0.0
# 1298                 Mexico     0.0
# 1149                     UK     0.0
#
# [3881 rows x 3 columns]

# %% [markdown]
# Sedaj lahko pogledamo, kako so v povprečju rumi ocenjeni v posameznih državah.

# %%
rating=rumi.groupby('Country')[['Rating']].mean().sort_values('Rating', ascending=False)
rating
# Out:
#                              Rating
# Country
# British Virgin Islands    10.000000
# Switzerland                9.000000
# Belgium                    8.083333
# Western Australia          8.000000
# Portugal                   8.000000
# Multiple                   7.942857
# British Virgin Isles       7.853333
# French Guyana              7.800000
# Honduras                   7.460000
# Turks and Caicos Islands   7.440000
# ...                             ...
# Cayman Islands             1.840000
# Estonia                    1.500000
# Ecuador                    1.353333
# French Polynesia           1.166667
# unknown                    0.500000
# Taiwan                     0.000000
# Jamaica &amp; Guyana       0.000000
# London                     0.000000
# Brasil                     0.000000
# usa                        0.000000
#
# [112 rows x 1 columns]

# %% [markdown]
# V oči mi pade ocena vodilnega ruma, zato preverim kaj se je utegnilo zgoditi, da je tako dobro ocenjen.

# %%
rumi[rumi['Country'] == 'British Virgin Islands']
# Out:
#                          Name                 Country    Type  Ratings  \
# 535  Sebastian's Sebastian's   British Virgin Islands  Spiced        1
#
#     Price_USD  Rating
# 535      None    10.0

# %% [markdown]
# In res, kot lahko vidim, rum Sebastian's Sebastian's je bil ocenjen z 10, a je prejel le en glas. Zato zgornja tabela ni najbolj primerna za določitev, katera država je najboljša v pridelavi ruma.

# %% [markdown]
# Lahko pa preverim, kateri rum prejme največ glasov in je na koncu najbolje ocenjen.

# %%
# najprej uredi padajoče po številu glasov, pri vsaki pa še padajoče po oceni...NAJBOLJSI RUM, najbolsa ocena in najvec glasov!!!
tabela2 = rumi1[['Name','Country','Rating', 'Ratings']].sort_values(['Ratings', 'Rating'], ascending=[False, False])
tabela2
# Out:
#                                                    Name      Country  Rating  \
# 0                        Diplomatico Reserva Exclusiva     Venezuela     8.1
# 7                                 Ron Zacapa 23 Solera     Guatemala     7.7
# 2                                  Kraken Black Spiced      Trinidad     6.2
# 1                                             Pyrat XO      Anguilla     6.3
# 4                                    El Dorado 12-Year        Guyana     7.8
# 3                       Plantation XO 20th Anniversary     Caribbean     8.6
# 9                    El Dorado Special Reserve 15-Year        Guyana     8.1
# 17                                  Havana Club 7-Year          Cuba     6.4
# 6                                        Ron Zacapa XO     Guatemala     8.8
# 10                           Zaya Gran Reserva 12-Year      Trinidad     7.5
# ...                                                 ...          ...     ...
# 606                              Kingston Black Cherry      Barbados     1.0
# 642                        Trois Rivieres Or Blanc Rhum   Martinique     1.0
# 671                Rones finos de colima Classico No.3        Mexico     1.0
# 728                                       Tirado Black           USA     1.0
# 735   James Busby Fine Wines &amp; Spirits Club Armada     Australia     1.0
# 3554               Rum company of Fiji Bounty Dark Rum          Fiji     1.0
# 3592                            New Grove Orange Bliss     Mauritius     1.0
# 3727                      Kahakai Tiki Spiced Original       unknown     1.0
# 3729                                     Tanduay White   Philippines     1.0
# 3766                             Ron Cabo Blanco Limon          Peru     1.0
#
#       Ratings
# 0        1235
# 7        1108
# 2         757
# 1         655
# 4         647
# 3         626
# 9         479
# 17        473
# 6         431
# 10        425
# ...       ...
# 606         1
# 642         1
# 671         1
# 728         1
# 735         1
# 3554        1
# 3592        1
# 3727        1
# 3729        1
# 3766        1
#
# [2953 rows x 4 columns]

# %% [markdown]
# Kot lahko vidimo, najbolje ocenjen rum je Diplomatico Reserva Exclusiva (Venezuela), ki je prejel 1235 glasov in ima oceno 8,1.

# %%
tabela2.groupby('Rating').mean().plot()

# %% [markdown]
# Nekateri rumi nimajo podane cene, zato jih bom v prihodnje obravnavala le tiste, ki ceno imajo.

# %%
popravljene_cene = rumi_s_ceno[['Price_USD']].apply(pd.to_numeric)
rumi_s_ceno = rumi_s_ceno.assign(Price_USD = popravljene_cene)
rumi_s_ceno
# Out:
#                                                   Name             Country  \
# 0                       Diplomatico Reserva Exclusiva            Venezuela
# 1                                            Pyrat XO             Anguilla
# 2                                 Kraken Black Spiced             Trinidad
# 3                      Plantation XO 20th Anniversary            Caribbean
# 4                                   El Dorado 12-Year               Guyana
# 5                                    Bacardi Superior          Puerto Rico
# 6                                       Ron Zacapa XO            Guatemala
# 7                                Ron Zacapa 23 Solera            Guatemala
# 8                      Matusalem Gran Reserva 15-Year   Dominican Republic
# 9                   El Dorado Special Reserve 15-Year               Guyana
# ...                                                ...                 ...
# 3765                           Berry's Panama 10-Year            Caribbean
# 3770  Bristol Classic Demerara Rum Ennmore Still 1988                   UK
# 3787                             Santiago de Cuba 500                 Cuba
# 3790                           Berry's Fijian 10-Year            Caribbean
# 3844                       Berry's Nicaraguan 11-Year            Caribbean
# 3853                            La Mauny Extra Saphir           Martinique
# 3855                                   Bear Hug Mango                  USA
# 3859                Malecon Seleccion Esplendida 1982               Panama
# 3871                       Blue Bay B. Superior White            Mauritius
# 3878              Saint James Cuvee 250th Anniversary           Martinique
#
#           Type  Ratings  Price_USD  Rating
# 0         Aged     1235      38.64     8.1
# 1         Aged      655      23.73     6.3
# 2       Spiced      757      17.30     6.2
# 3         Aged      626      54.76     8.6
# 4         Aged      647      36.11     7.8
# 5        Light      367      14.26     3.7
# 6         Aged      431      94.80     8.8
# 7         Aged     1108      50.70     7.7
# 8         Aged      368      28.93     6.4
# 9         Aged      479      52.61     8.1
# ...        ...      ...        ...     ...
# 3765      Aged        1      72.42     7.0
# 3770      Aged        1     214.78    10.0
# 3787      Aged        1    4771.33    10.0
# 3790      Aged        1      67.92     5.0
# 3844      Aged        1      90.87     8.0
# 3853      Aged        1     168.64     9.0
# 3855  Flavored        1      33.10     6.0
# 3859      Aged        1     170.26     9.0
# 3871     Light        1      18.49     3.0
# 3878      Aged        1    1120.57     3.0
#
# [711 rows x 6 columns]

# %% [markdown]
# Zgolj iz radovednosti želim preverit, ali se cena ruma res povečuje z boljšo oceno. Spodnji graf pa mi to potrdi.

# %%
rumi_s_ceno.groupby('Rating').mean().plot(y = 'Price_USD')

# %% [markdown]
# Iz zgornjega grafa vidim tudi, da so nekatere cene rumov visoke, in me zanima, od kod prihajajo najdražji rumi.

# %%
rumi_s_ceno[['Name','Country', 'Price_USD']].sort_values(by =('Price_USD'),ascending = (False))
# Out:
#                                                    Name             Country  \
# 3787                              Santiago de Cuba 500                 Cuba
# 1050                            Edmundo Dantes 25-Year                 Cuba
# 3878               Saint James Cuvee 250th Anniversary           Martinique
# 1137                                   Neisson 21-Year           Martinique
# 1059                 Clement Rhum vieux Millesime 1952           Martinique
# 1760  Chantal Comte Plantation de la Montagne Pelee XO               France
# 1817                            El Dorado Millenium 25               Guyana
# 2793                 Clement Rhum vieux Millesime 1970           Martinique
# 935                                    Neisson 15-Year           Martinique
# 1966                                 Havana Club Union                 Cuba
# ...                                                 ...                 ...
# 3212                             Macollo Black 12-Year               Mexico
# 134                                   Opthimus 18-Year   Dominican Republic
# 75                                    Opthimus 15-Year   Dominican Republic
# 31                                    Dictador 12-Year             Colombia
# 487                                  Ron Cartavio 1929                 Peru
# 1107                              Macollo Anejo 7-Year               Mexico
# 2566                                         Borgoe 82             Suriname
# 2559                                         Borgoe 82             Suriname
# 183                                     Summum 12-Year             Trinidad
# 2412                    Havana Club Maximo Extra Anejo                 Cuba
#
#       Price_USD
# 3787    4771.33
# 1050    1126.52
# 3878    1120.57
# 1137    1118.24
# 1059    1108.43
# 1760     921.85
# 1817     713.82
# 2793     710.45
# 935      627.00
# 1966     428.10
# ...         ...
# 3212       8.55
# 134        7.34
# 75         7.13
# 31         6.83
# 487        6.81
# 1107       6.75
# 2566       6.66
# 2559       6.64
# 183        5.63
# 2412       1.34
#
# [711 rows x 3 columns]

# %% [markdown]
# Najvišje v tabeli je rum:

# %%
rumi[rumi['Price_USD'] == '4771.33']
# Out:
#                        Name Country  Type  Ratings Price_USD  Rating
# 3787  Santiago de Cuba 500     Cuba  Aged        1   4771.33    10.0

# %% [markdown]
# Poglejmo si še, kako so povprečne ocene ter cena odvisni od stila.

# %%
rumi_s_ceno.groupby('Type')[['Rating','Price_USD']].mean().sort_values('Rating', ascending=False)
# Out:
#                  Rating   Price_USD
# Type
# Aged           6.503325   97.400486
# Rhum Agricole  6.272414   77.261034
# Overproof      6.086667   37.307333
# Spiced         5.907143   34.156071
# Dark           5.772222   28.454444
# Cachaca        5.500000   33.030000
# Gold           5.255285   31.849431
# Light          4.119444   50.286389
# Flavored       3.930303   28.841212
# n/a            0.000000  169.370000

# %% [markdown]
# Na koncu pa me zanima, kateri rum bi bil najboljši nakup. To bi pomenilo, da ima pri največjem številu glasov najboljšo oceno in ima temu ugodno ceno.

# %%
rumi_s_ceno.sort_values(['Ratings','Rating','Price_USD'],ascending=[False,False,False])[:10]
# Out:
#                                   Name    Country    Type  Ratings  Price_USD  \
# 0       Diplomatico Reserva Exclusiva   Venezuela    Aged     1235      38.64
# 7                Ron Zacapa 23 Solera   Guatemala    Aged     1108      50.70
# 2                 Kraken Black Spiced    Trinidad  Spiced      757      17.30
# 1                            Pyrat XO    Anguilla    Aged      655      23.73
# 4                   El Dorado 12-Year      Guyana    Aged      647      36.11
# 3      Plantation XO 20th Anniversary   Caribbean    Aged      626      54.76
# 9   El Dorado Special Reserve 15-Year      Guyana    Aged      479      52.61
# 17                 Havana Club 7-Year        Cuba    Aged      473      25.00
# 6                       Ron Zacapa XO   Guatemala    Aged      431      94.80
# 10          Zaya Gran Reserva 12-Year    Trinidad    Aged      425      30.99
#
#     Rating
# 0      8.1
# 7      7.7
# 2      6.2
# 1      6.3
# 4      7.8
# 3      8.6
# 9      8.1
# 17     6.4
# 6      8.8
# 10     7.5

# %% [markdown]
# Če želimo piti najboljši rum po najugodnješi ceni, potem nam zgornja tabela pove, kateri to je:
